# %%
import numpy as np
import pandas as pd
from numpy.random import randn
from scipy import stats
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# //anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
# %matplotlib inline

# %%
dataset1 = randn(100)

# %%
plt.hist(dataset1)
# Out:
# (array([  2.,   2.,   7.,  13.,  13.,  19.,  23.,   9.,   9.,   3.]),
#  array([-2.67476603, -2.19029472, -1.70582342, -1.22135211, -0.7368808 ,
#         -0.2524095 ,  0.23206181,  0.71653312,  1.20100442,  1.68547573,
#          2.16994704]),
#  <a list of 10 Patch objects>)

# %%
dataset2 = randn(80)

# %%
plt.hist(dataset2,color='indianred')
# Out:
# (array([  2.,   1.,   7.,   7.,   9.,  13.,  15.,  13.,   8.,   5.]),
#  array([-3.27591298, -2.72614817, -2.17638336, -1.62661854, -1.07685373,
#         -0.52708892,  0.0226759 ,  0.57244071,  1.12220553,  1.67197034,
#          2.22173515]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(dataset1,normed=True,color='indianred',alpha = 0.5, bins = 20)
plt.hist(dataset2,normed=True,alpha = 0.5,bins=20)
# Out:
# (array([ 0.04547399,  0.04547399,  0.        ,  0.04547399,  0.18189596,
#          0.13642197,  0.18189596,  0.13642197,  0.18189596,  0.22736995,
#          0.27284394,  0.31831793,  0.5002139 ,  0.18189596,  0.31831793,
#          0.27284394,  0.13642197,  0.22736995,  0.09094798,  0.13642197]),
#  array([-3.27591298, -3.00103058, -2.72614817, -2.45126576, -2.17638336,
#         -1.90150095, -1.62661854, -1.35173614, -1.07685373, -0.80197132,
#         -0.52708892, -0.25220651,  0.0226759 ,  0.29755831,  0.57244071,
#          0.84732312,  1.12220553,  1.39708793,  1.67197034,  1.94685275,
#          2.22173515]),
#  <a list of 20 Patch objects>)

# %%
data1 = randn(1000)
data2 = randn(1000)

# %%
#kernel density estimation

# %%
dataset = randn(25)

# %%
sns.rugplot(dataset)
plt.ylim(0,1)
# Out:
# (0, 1)

# %%
plt.hist(dataset,alpha=0.3)
sns.rugplot(dataset)

# %%
sns.rugplot(dataset)
x_min = dataset.min()-2
x_max = dataset.max()+2

x_axis = np.linspace(x_min,x_max,100)

bandwidth = ((4*dataset.std()**5)/(3*len(dataset)))**2

kernel_list = []

for data_point in dataset:
    kernel = stats.norm(data_point,bandwidth).pdf(x_axis)
    kernel_list.append(kernel)
    
    kernel = kernel / kernel.max()
    kernel = kernel*0.4
    
    plt.plot(x_axis,kernel, color = 'grey', alpha = 0.5)

plt.ylim(0,1)
# Out:
# (0, 1)

# %%
sum_of_kde = np.sum(kernel_list,axis=0)

# %%
fig = plt.plot(x_axis, sum_of_kde, color = 'indianred')
sns.rugplot(dataset)
plt.yticks([])
plt.suptitle("Sum of basis functions")

# %%
sns.kdeplot(dataset)

# %%
sns.rugplot(dataset,color='black')

for bw in np.arange(0.5,2,0.25):
    sns.kdeplot(dataset,bw=bw,lw=1.8,label=bw)

# %%
kernel_options = ['biw','cos','epa','gau','tri','triw']
for kern in kernel_options:
    sns.kdeplot(dataset,kernel=kern,label=kern,shade=True)

# %%
sns.kdeplot(dataset,vertical=True)

# %%
sns.kdeplot(dataset, cumulative=True)

# %%
mean = [0,0]
cov = [[1,0],[0,100]]

dataset2 = np.random.multivariate_normal(mean, cov, 1000)

# %%
from pandas import DataFrame

# %%
dframe = DataFrame(dataset2,columns = ['X','Y'])
sns.kdeplot(dframe)

# %%
dframe.head()
# Out:
#           X         Y
# 0 -1.186978  3.610749
# 1 -0.168770  7.345123
# 2  0.622348  1.766471
# 3 -0.423264 -9.269187
# 4  0.623875  4.728718

# %%
sns.kdeplot(dframe.X,dframe.Y,bw=1)

# %%
sns.kdeplot(dframe,bw='silverman')

# %%
sns.jointplot('X','Y',dframe,kind='kde')

# %%
dataset11=randn(100)

# %%
sns.distplot(dataset11,bins=25)
#combines kde with histogram

# %%
sns.distplot(dataset11,rug=True,hist=False,bins=25)

# %%
sns.distplot(dataset11,bins=25,
              kde_kws={'color':'indianred','label':'KDE PLOT'},
              hist_kws = {'color':'blue','label':'HIST'})

# %%
from pandas import Series
ser1 = Series(dataset11,name='My_data')

# %%
sns.distplot(ser1,bins=25)
